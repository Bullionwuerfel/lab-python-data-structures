# %%
products=("t-shirt", "mug", "hat", "book", "keychain")

inventory={}

for i in products:
  quantity = int(input(f"how many do we have of this item:{i}?"))
  inventory[i]=quantity

customer_orders=set()

for i in range(3):
  customer_orders.add(input(f"please choose an item to order from this list ({i+1}/3):{products}"))


TPO= len(customer_orders)

totalnumerofprod=0
for i in inventory:
  totalnumerofprod+=inventory[i]

PPO= (len(customer_orders)*100)//totalnumerofprod

print("Order Statistics:")

print(f"Total Products Ordered: {TPO}")
print(f"Percentage of Products Ordered: {PPO}")

for i in  customer_orders:
  inventory[i]-=1

print(inventory)
# Out:
# how many do we have of this item:t-shirt?5
# how many do we have of this item:mug?5
# how many do we have of this item:hat?5
# how many do we have of this item:book?5
# how many do we have of this item:keychain?5
# please choose an item to order from this list (1/3):('t-shirt', 'mug', 'hat', 'book', 'keychain')hat
# please choose an item to order from this list (2/3):('t-shirt', 'mug', 'hat', 'book', 'keychain')mug
# please choose an item to order from this list (3/3):('t-shirt', 'mug', 'hat', 'book', 'keychain')book
# Order Statistics:
# Total Products Ordered: 3
# Percentage of Products Ordered: 12
# {'t-shirt': 5, 'mug': 4, 'hat': 4, 'book': 4, 'keychain': 5}
